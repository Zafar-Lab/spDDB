# %%
# !STRIDE --help
# Out:
# /home/ajita/anaconda3/envs/STRIDE/bin/STRIDE:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').run_script('stridespatial==0.0.2a0', 'STRIDE')
# usage: STRIDE [-h] [-v] {deconvolve,plot,cluster,integrate,map} ...
#
# STRIDE (Spatial TRanscrIptomics DEconvolution by topic modelling) is a cell-
# type deconvolution tool for spatial transcriptomics by using single-cell
# transcriptomics data.
#
# positional arguments:
#   {deconvolve,plot,cluster,integrate,map}
#     deconvolve          Decompose celltype proportion for spatial
#                         transcriptomics.
#     plot                Visualize the deconvolution result.
#     cluster             Neighbourhood analysis based on cell-type composition
#                         and local cell population
#     integrate           Integrate multiple samples from the same tissue.
# ...

# %% [markdown]
# !STRIDE deconvolve --sc-count SC.h5ad \
# --sc-celltype celltype.txt \
# --st-count 151674_filtered_feature_bc_matrix.h5 \
# --outdir ./result/ \
# --outprefix dlpfc --normalize

# %% [markdown]
# ### ER+

# %%
# !STRIDE deconvolve --sc-count /data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Cancer/SC/CID4290_SC_filtered.h5ad \
--st-count /data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Cancer/simulator_outputs/ER+/simulated_gene_expression_average.h5ad \
--outdir /data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Cancer/final_outputs/ER+/ \
--outprefix output_STRIDE --normalize
# Out:
# /home/ajita/anaconda3/envs/STRIDE/bin/STRIDE:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').run_script('stridespatial==0.0.2a0', 'STRIDE')
# Reading spatial count matrix...
# /home/ajita/anaconda3/envs/STRIDE/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:248: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_counts'] = number
# count per spot [ 8567  1956  2949 ... 19164  5132  1538]
# Reading single-cell count matrix...
# (27576, 34541) SHAPE
# Identifying markers...
# rank genes group starts
# ...
