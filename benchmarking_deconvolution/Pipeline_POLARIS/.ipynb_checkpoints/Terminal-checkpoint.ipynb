# %%
import anndata as an
import pandas as pd
import sklearn as sk
import torch as t

# %%
sc = an.read_h5ad("./SC/C.h5ad")
sc_labels = sc.obs.celltype

# %%
sc_labels.to_csv("./POLARIS/SC_labels.tsv",sep='\t', index=True, header=True)

# %%
# !python3 train.py \
--sc_cnt ./SC/CID4290_SC_filtered.h5ad \
--sc_labels ./POLARIS/SC_labels.tsv \
--st_cnt ./simulated_gene_expression_average.h5ad \
--st_source simulation --st_batch_size 1024 --sc_batch_size 1024 --st_epochs 2000 --sc_epochs1 2000 \
--gpu --out_dir ./POLARIS/Outputs --prefix sample \
--st_label /data/keerthana/Spatial/Spatial_convolution/POLARIS/simulated_ER_ST_labels.tsv
# Out:
# /home/keerthana/anaconda3/envs/polaris/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/keerthana/anaconda3/envs/polaris/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
#
#
# No image for simulation
#
#
# Epoch : 2000/2000 | Loss : 1.846824E+08 | [ =================== ]
#
# Starting ST final training
# TYPE <class 'torch.nn.modules.sparse.Embedding'> ___ Embedding(9, 11854)
# TYPE <class 'torch.nn.modules.sparse.Embedding'> ___ Embedding(9, 11854)
# TYPE <class 'torch.nn.modules.sparse.Embedding'> ___ Embedding(9, 11854)
# ...

# %%
end - start

# %%
ann.read_h5ad("/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/DLPFC/simulator_outputs/simulated_gene_expression151508_average.h5ad")

# %%
str = "0&-ATGKCKAS"
zip(*[str.split("&-")])

# %%
enumerate("/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/DLPFC/simulator_outputs/simulated_gene_expression151508_average.h5ad")

# %%
import pandas as pd

# %%
res= pd.read_csv("/home/keerthana/Documents/Spatial/Fall23/Temp/151508/heart_noimage.tsv", delimiter = "\t")

# %%
r = res[res.columns[1:]]

# %%
r.sum(axis = 1)

# %%
res.index = res.iloc[:,0]
res = res.iloc[:,]
