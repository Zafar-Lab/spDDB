# %%
import rpy2
# %load_ext rpy2.ipython

# pip install rpy2
#https://bioconductor.org/packages/release/bioc/vignettes/countsimQC/inst/doc/countsimQC.html
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# source("countsimQC.R")

# %% [markdown]
# %%R
#
# #testing module
#
# slice_id <- "410"
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Cancer/ST/6800STDY12499"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Cancer/simulator_outputs/simulated_gene_expression_"
#
# orig_data_path <- paste0(paste0(path, slice_id), "_ST.h5ad")
# sim_data_path <- paste0(paste0(sim_path, slice_id), "_average.h5ad")
#
# ann_orig <- read_h5ad(orig_data_path)
# ann_sim <- read_h5ad(sim_data_path)
#
# genes_orig <- ann_orig$var_names
# genes_sim <- ann_sim$var_names
# common_genes <- intersect(genes_orig, genes_sim)
#
# obs_orig <- ann_orig$obs_names
# obs_sim <- ann_sim$obs_names
# cells_to_filter <- intersect(obs_orig, obs_sim)
#
# ann_filtered <- ann_orig[ , colnames(ann_orig) %in% common_genes]
# ann_filtered <- ann_filtered[ann_filtered$obs_names %in% cells_to_filter, ]
#
# print (ann_filtered$shape)
# print (ann_sim$shape)

# %% [markdown]
# ### Kidney Cancer

# %%
# %%R
#
# ddsList <- list()
# tempDir <- "./"
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Cancer/ST/6800STDY12499"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Cancer/simulator_outputs/simulated_gene_expression_"
#
# #410
# for (slice_id in list("411", "506")) {
#     ddsList <- list()
#     orig_data_path <- paste0(paste0(path, slice_id), "_ST.h5ad")
#     sim_data_path <- paste0(paste0(sim_path, slice_id), "_average.h5ad")
#
#     dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#     dds2 <- convert_ann2dds(sim_data_path)
#     ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#     ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#     countsim_plots(ddsList, paste0("Kidney_Cancer_", slice_id))
#     individual_plots(paste0("Kidney_Cancer_", slice_id))
# }
# Out:
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
# NULL
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
# NULL
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Breast Cancer

# %%
# %%R
#
#
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Cancer/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Cancer/simulator_outputs/"
#
# for (slice_id in list("ER+_CID4290", "TNBC_CID44971")) {
#
#   ddsList <- list()
#   orig_data_path <- paste0(paste0(path, slice_id), "_ST.h5ad")
#   sim_data_path <- paste0(paste0(sim_path, slice_id), "/simulated_gene_expression_average.h5ad")
#
#   dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#   dds2 <- convert_ann2dds(sim_data_path)
#   ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#   ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#   countsim_plots(ddsList, paste0("Breast_Cancer", slice_id))
#   individual_plots(paste0("Breast_Cancer", slice_id))
# }
# Out:
# [1]  2432 11854
# [1]  2432 11854
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'
# [1]  1162 12353
# [1]  1162 12353
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Liver Cancer

# %% [markdown]
# %%R
# BiocManager::install("zellkonverter")

# %% [markdown]
# sce <- readH5AD(orig_data_path)
# counts <- assay(sce, "X")
# if (is(counts, "sparseMatrix")){
#     counts <- as.matrix(counts)
# }
# coldata <- colData(sce)
#
# dds <- DESeqDataSetFromMatrix(countData = counts, colData = coldata, design = ~1)

# %%
# %%R
#
# # kernel died so doing the slices separately...
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Cancer/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Cancer/simulator_outputs/simulated_gene_expression_"
#
# #HCC-1L -> kernel restarting, 2L -> kernel restarting, 3L->kernel restarting, 4L -> kernel restarting
# for (slice_id in list("HCC-4L")) {
#   ddsList <- list()
#   orig_data_path <- paste0(paste0(path, slice_id), "_ST.h5ad")
#   sim_data_path <- paste0(paste0(sim_path, slice_id), "_average.h5ad")
#
#   dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#   dds2 <- convert_ann2dds(sim_data_path)
#   ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#   ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#   countsim_plots(ddsList, paste0("Liver_Cancer", slice_id))
#   individual_plots(paste0("Liver_Cancer", slice_id))
# }
# Out:
# [1] 4113 7103
# [1] 4113 7093
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode

# %% [markdown]
# ### Prostate Cancer

# %%
# %%R
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Prostate_Cancer/ST/S9_ST.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Prostate_Cancer/simulator_outputs/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Prostate_Cancer/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Prostate_Cancer/simulator_outputs/simulated_gene_expression_"
#
# slice_id <- ""
#
# ddsList <- list()
# orig_data_path <- paste0(paste0(path, slice_id), "S9_ST.h5ad")
# sim_data_path <- paste0(paste0(sim_path, slice_id), "average.h5ad")
#
# dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
# dds2 <- convert_ann2dds(sim_data_path)
# ddsList[[ paste0("Orig_", slice_id)]] <- dds1
# ddsList[[ paste0("Sim_", slice_id)]] <- dds2
# countsim_plots(ddsList, paste0("Prostate_Cancer", slice_id))
# individual_plots(paste0("Prostate_Cancer", slice_id))
# Out:
# [1] 23945 24728
# [1] 23945 24728
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Lung Cancer Visium HD

# %%
# %%R
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Human_Lung_Cancer_VisiumHD/ST/ST.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Human_Lung_Cancer_VisiumHD/simulator_outputs/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Human_Lung_Cancer_VisiumHD/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Human_Lung_Cancer_VisiumHD/simulator_outputs/simulated_gene_expression_"
#
# slice_id <- ""
#
# ddsList <- list()
# orig_data_path <- paste0(paste0(path, slice_id), "ST.h5ad")
# sim_data_path <- paste0(paste0(sim_path, slice_id), "average.h5ad")
#
# dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
# dds2 <- convert_ann2dds(sim_data_path)
# ddsList[[ paste0("Orig_", slice_id)]] <- dds1
# ddsList[[ paste0("Sim_", slice_id)]] <- dds2
# countsim_plots(ddsList, paste0("Human_Lung_Cancer_VisiumHD", slice_id))
# individual_plots(paste0("Human_Lung_Cancer_VisiumHD", slice_id))
# Out:
# [1] 150589  15462
# [1] 150589  17797
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'
# R[write to console]: There were 16 warnings (use warnings() to see them)
# R[write to console]:
