# %%
import rpy2
# %load_ext rpy2.ipython

# %%
# %%R
# source("countsimQC.R")
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# R[write to console]: Loading required package: MatrixGenerics
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘MatrixGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
# ...

# %% [markdown]
# https://bioconductor.org/packages/release/bioc/vignettes/countsimQC/inst/doc/countsimQC.html

# %% [markdown]
# ### Developmental Lung

# %%
# %%R
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Developmental_Lung/ST"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Developmental_Lung/simulator_outputs/simulated_gene_expression"
#
# slice_id = ""
# ddsList <- list()
# orig_data_path <- paste0(paste0(path, slice_id), "/ST.h5ad")
# sim_data_path <- paste0(paste0(sim_path, slice_id), "_average.h5ad")
#
# dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
# dds2 <- convert_ann2dds(sim_data_path)
# name1 <- paste0("Orig_", slice_id)
# name2 <- paste0("Sim_", slice_id)
#
# ddsList[[ paste0("Orig_", slice_id)]] <- dds1
# ddsList[[ paste0("Sim_", slice_id)]] <- dds2
# #ddsList <- c( ddsList, list(name1 = dds1, name2 = dds2))
# countsim_plots(ddsList, "Developmental_Lung")
# individual_plots("Developmental_Lung")
# Out:
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# [1]  3044 20385
# [1]  3044 20374
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Breast Atlas

# %%
# %%R
#
# ddsList <- list()
# tempDir <- "./"
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Atlas/simulator_outputs/ST_1/simulated_gene_expression_average.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Atlas/ST/ST_1.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Atlas/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Breast_Atlas/simulator_outputs/"
#
# #ST_1
# for (slice_id in list("ST_8")) {
#
#     ddsList <- list()
#     orig_data_path <- paste0(paste0(path, slice_id), ".h5ad")
#     sim_data_path <- paste0(paste0(sim_path, slice_id), "/simulated_gene_expression_average.h5ad")
#
#     dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#     dds2 <- convert_ann2dds(sim_data_path)
#     ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#     ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#     countsim_plots(ddsList, paste0("Breast_Atlas_", slice_id))
#     individual_plots(paste0("Breast_Atlas_", slice_id))
# }
# Out:
# WARNING: Ignoring invalid distribution -umpy (/home/ajita/anaconda3/lib/python3.9/site-packages)
# [1]  2801 32664
# [1]  2801 32664
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Intestine

# %%
# %%R
#
# ddsList <- list()
# tempDir <- "./"
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Intestine/ST/A1/ST.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Intestine/simulator_outputs/A1/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Intestine/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Intestine/simulator_outputs/"
#
# #A1
# for (slice_id in list("A2")) {
#
#     ddsList <- list()
#     orig_data_path <- paste0(paste0(path, slice_id), "/ST.h5ad")
#     sim_data_path <- paste0(paste0(sim_path, slice_id), "/simulated_gene_expression_average.h5ad")
#
#     dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#     dds2 <- convert_ann2dds(sim_data_path)
#     ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#     ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#     countsim_plots(ddsList, paste0("Intestine_", slice_id))
#     individual_plots(paste0("Intestine_", slice_id))
# }
# Out:
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# [1]  2315 13548
# [1]  2315 13541
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Chicken Heart

# %%
# %%R
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/ChickenHeart/ST/ST_D10.h5ad"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/ChickenHeart/simulator_outputs/simulated_gene_expression_average.h5ad"
#
# slice_id = ""
# ddsList <- list()
# orig_data_path <- paste0(paste0(path, slice_id), "")
# sim_data_path <- paste0(paste0(sim_path, slice_id), "")
#
# dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
# dds2 <- convert_ann2dds(sim_data_path)
# name1 <- paste0("Orig_", slice_id)
# name2 <- paste0("Sim_", slice_id)
#
# ddsList[[ paste0("Orig_", slice_id)]] <- dds1
# ddsList[[ paste0("Sim_", slice_id)]] <- dds2
# #ddsList <- c( ddsList, list(name1 = dds1, name2 = dds2))
# countsim_plots(ddsList, "Chicken_Heart")
# individual_plots("Chicken_Heart")
# Out:
# [1] 1915 3688
# [1] 1915 3688
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Liver Atlas

# %%
# %%R
#
# ddsList <- list()
# tempDir <- "./"
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/ST/Mouse/ST4.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/simulator_outputs/Mouse/4/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/ST/Mouse/ST"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/simulator_outputs/Mouse/"
#
# #410
# for (slice_id in list("4", "12")) {
#
#     ddsList <- list()
#     orig_data_path <- paste0(paste0(path, slice_id), ".h5ad")
#     sim_data_path <- paste0(paste0(sim_path, slice_id), "/simulated_gene_expression_average.h5ad")
#
#     dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#     dds2 <- convert_ann2dds(sim_data_path)
#     ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#     ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#     countsim_plots(ddsList, paste0("Liver_Atlas_Mouse_", slice_id))
#     individual_plots(paste0("Liver_Atlas_Mouse_", slice_id))
# }
# Out:
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
# NULL
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode

# %%
# %%R
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/ST/Human/ST18.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/simulator_outputs/Human/18/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/ST/Human/ST18.h5ad"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Liver_Atlas/simulator_outputs/Human/18/simulated_gene_expression_average.h5ad"
#
# slice_id = "18"
# ddsList <- list()
# orig_data_path <- path #paste0(paste0(path, slice_id), "")
# sim_data_path <- sim_path #paste0(paste0(sim_path, slice_id), "")
#
# dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
# dds2 <- convert_ann2dds(sim_data_path)
# name1 <- paste0("Orig_", slice_id)
# name2 <- paste0("Sim_", slice_id)
#
# ddsList[[ paste0("Orig_", slice_id)]] <- dds1
# ddsList[[ paste0("Sim_", slice_id)]] <- dds2
# #ddsList <- c( ddsList, list(name1 = dds1, name2 = dds2))
# countsim_plots(ddsList, "Liver_Atlas_Human")
# individual_plots("Liver_Atlas_Human")
# Out:
# /home/ajita/anaconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# [1]  1759 32738
# [1]  1759 32643
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# ### Kidney Atlas

# %%
# %%R
#
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Atlas/ST/200903_1/ST.h5ad
# #/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Atlas/simulator_outputs/200903_1/simulated_gene_expression_average.h5ad
#
# path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Atlas/ST/"
# sim_path <- "/data/Ajita/Spatial/Datasets/Spatial_Deconvolution/Kidney_Atlas/simulator_outputs/"
#
#
# for (slice_id in list("200903_1", "200903_6")) {
#   ddsList <- list()
#   orig_data_path <- paste0(paste0(path, slice_id), "/ST.h5ad")
#   sim_data_path <- paste0(paste0(sim_path, slice_id), "/simulated_gene_expression_average.h5ad")
#
#   dds1 <- convert_ann2dds_original(orig_data_path, sim_data_path)
#   dds2 <- convert_ann2dds(sim_data_path)
#   name1 <- paste0("Orig_", slice_id)
#   name2 <- paste0("Sim_", slice_id)
#
#   ddsList[[ paste0("Orig_", slice_id)]] <- dds1
#   ddsList[[ paste0("Sim_", slice_id)]] <- dds2
#   #ddsList <- c( ddsList, list(name1 = dds1, name2 = dds2))
#   countsim_plots(ddsList, slice_id)
#   individual_plots(paste0(slice_id))
# }
# Out:
# WARNING: Ignoring invalid distribution -umpy (/home/ajita/anaconda3/lib/python3.9/site-packages)
# [1] 20852 16584
# [1] 20852 16584
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'
# [1] 30296 16799
# [1] 30296 16799
# R[write to console]: The matrix is sparse
#
# R[write to console]: converting counts to integer mode
#
# R[write to console]: The matrix is already dense
#
# R[write to console]: converting counts to integer mode
# `geom_smooth()` using formula = 'y ~ x'
